# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("olegshpagin/extra-us-stocks-market-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 8.05G/8.05G [01:25<00:00, 101MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2

# %%
tickers = ["AAPL.US", "AMZN.US", "MSFT.US", "NVDA.US", "TSLA.US", "GOOGL.US", ]
names = ["Apple", "Amazon", "Microsoft", "Nvidia", "Tesla", "Google"]
timeframe = "D1"

ticker = "AMZN.US"
df_AMZN = pd.read_csv(f"/root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/{timeframe}/{ticker}_{timeframe}.csv")
df_AMZN
# Out:
#         datetime    open    high     low   close    volume  \
# 0     1998-01-02    3.00    3.00    2.87    2.97   2646000
# 1     1998-01-05    2.93    2.96    2.82    2.85   5762000
# 2     1998-01-06    2.81    2.92    2.80    2.89   6258000
# 3     1998-01-07    2.90    2.90    2.81    2.86   4500000
# 4     1998-01-08    2.81    2.82    2.71    2.76   9898000
# ...          ...     ...     ...     ...     ...       ...
# 6572  2023-12-22  153.94  154.35  152.71  153.49  19378362
# 6573  2023-12-23  153.48  153.49  153.44  153.45     37069
# 6574  2023-12-26  153.56  153.98  153.03  153.45  17098236
# 6575  2023-12-27  153.45  154.78  153.12  153.39  21503936
# 6576  2023-12-28  153.40  154.08  152.95  153.36  22833195
#
#       bbands_3_upperband  bbands_3_middleband  bbands_3_lowerband  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# ...

# %%
import os

for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/ReadMe.md
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/FTV.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/WRB.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/MLM.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/WFC.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/PNR.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/BWA.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/BKR.US_D1.csv
# /root/.cache/kagglehub/datasets/olegshpagin/extra-us-stocks-market-data/versions/2/D1/MA.US_D1.csv
# ...

# %%
print(list(df_AAPL.columns))
# Out:
# ['datetime', 'open', 'high', 'low', 'close', 'volume', 'bbands_3_upperband', 'bbands_3_middleband', 'bbands_3_lowerband', 'bbands_4_upperband', 'bbands_4_middleband', 'bbands_4_lowerband', 'bbands_5_upperband', 'bbands_5_middleband', 'bbands_5_lowerband', 'bbands_6_upperband', 'bbands_6_middleband', 'bbands_6_lowerband', 'bbands_7_upperband', 'bbands_7_middleband', 'bbands_7_lowerband', 'bbands_8_upperband', 'bbands_8_middleband', 'bbands_8_lowerband', 'bbands_9_upperband', 'bbands_9_middleband', 'bbands_9_lowerband', 'bbands_10_upperband', 'bbands_10_middleband', 'bbands_10_lowerband', 'bbands_12_upperband', 'bbands_12_middleband', 'bbands_12_lowerband', 'bbands_14_upperband', 'bbands_14_middleband', 'bbands_14_lowerband', 'bbands_16_upperband', 'bbands_16_middleband', 'bbands_16_lowerband', 'bbands_18_upperband', 'bbands_18_middleband', 'bbands_18_lowerband', 'bbands_20_upperband', 'bbands_20_middleband', 'bbands_20_lowerband', 'bbands_25_upperband', 'bbands_25_middleband', 'bbands
# ...

# %%
import os

def get_size(path):
    total = 0

    if os.path.isfile(path):
        total = os.path.getsize(path)
    else:
        for root, dirs, files in os.walk(path):
            for file in files:
                total += os.path.getsize(os.path.join(root, file))

    return total

size_bytes = get_size(path)
size_gb = size_bytes / (1024 ** 3)

print(f"Dataset size: {size_gb:.2f} GB")
# Out:
# Dataset size: 24.08 GB

# %%
# Download latest version
path = kagglehub.dataset_download("debashis74017/stock-market-data-nifty-50-stocks-1-min-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.12G/1.12G [00:15<00:00, 77.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/debashis74017/stock-market-data-nifty-50-stocks-1-min-data/versions/15

# %%
import os

def get_size(path):
    total = 0

    if os.path.isfile(path):
        total = os.path.getsize(path)
    else:
        for root, dirs, files in os.walk(path):
            for file in files:
                total += os.path.getsize(os.path.join(root, file))

    return total

size_bytes = get_size(path)
size_gb = size_bytes / (1024 ** 3)

print(f"Dataset size: {size_gb:.2f} GB")
# Out:
# Dataset size: 5.26 GB

# %%
from datasets import load_dataset

# Load the dataset (will stream across all months)
ds = load_dataset("mito0o852/OHLCV-1m", split="train")

# View one row
print(ds[0])

# To convert it into a pandas DataFrame:

import pandas as pd

df = ds.to_pandas()
print(df.head())
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/411 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1572/3438603629.py in <cell line: 0>()
#       2
#       3 # Load the dataset (will stream across all months)
# ----> 4 ds = load_dataset("mito0o852/OHLCV-1m", split="train")
#       5
#       6 # View one row
#
# /usr/local/lib/python3.13/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
# ...

# %%
from datasets import load_dataset

ds = load_dataset("ggaddam/OHLCV-1m")
# Out:
# README.md:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/403 [00:00<?, ?it/s]
# ...
# data/ohlcv_1992-01.parquet: reconstructing file:   0%|          |  0.00B / 33.5MB
# data/ohlcv_1992-01.parquet: downloading bytes:           |  0.00B
# data/ohlcv_1992-02.parquet: reconstructing file:   0%|          |  0.00B / 26.3MB
# data/ohlcv_1992-02.parquet: downloading bytes:           |  0.00B
# data/ohlcv_1992-03.parquet: reconstructing file:   0%|          |  0.00B / 25.8MB
# data/ohlcv_1992-03.parquet: downloading bytes:           |  0.00B
# data/ohlcv_1992-04.parquet: reconstructing file:   0%|          |  0.00B / 25.4MB
# data/ohlcv_1992-04.parquet: downloading bytes:           |  0.00B
# data/ohlcv_1992-05.parquet: reconstructing file:   0%|          |  0.00B / 21.7MB
# data/ohlcv_1992-05.parquet: downloading bytes:           |  0.00B
# data/ohlcv_1992-06.parquet: reconstructing file:   0%|          |  0.00B / 24.1MB
# ...
